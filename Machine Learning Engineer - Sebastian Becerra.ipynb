# %% [markdown]
# # Trabajo de Juan

# %% [markdown]
# ## Problema
#
# El problema consiste en predecir la probabilidad de atraso de los vuelos que aterrizan o despegan del aeropuerto de Santiago
# de Chile (SCL). Para eso les entregamos un dataset usando datos públicos y reales donde cada fila corresponde a un vuelo
# que aterrizó o despegó de SCL. Para cada vuelo se cuenta con la siguiente información:
#
# * **Fecha-I** : Fecha y hora programada del vuelo.
# * **Vlo-I** : Número de vuelo programado.
# * **Ori-I** : Código de ciudad de origen programado.
# * **Des-I** : Código de ciudad de destino programado.
# * **Emp-I** : Código aerolínea de vuelo programado.
# * **Fecha-O** : Fecha y hora de operación del vuelo.
# * **Vlo-O** : Número de vuelo de operación del vuelo.
# * **Ori-O** : Código de ciudad de origen de operación
# * **Des-O** : Código de ciudad de destino de operación.
# * **Emp-O** : Código aerolínea de vuelo operado.
# * **DIA** : Día del mes de operación del vuelo.
# * **MES** : Número de mes de operación del vuelo.
# * **AÑO** : Año de operación del vuelo.
# * **DIANOM** : Día de la semana de operación del vuelo.
# * **TIPOVUELO** : Tipo de vuelo, I =Internacional, N =Nacional.
# * **OPERA** : Nombre de aerolínea que opera.
# * **SIGLAORI** : Nombre ciudad origen.
# * **SIGLADES** : Nombre ciudad destino.

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ### 0. Obtención de datos

# %%
#Se importan las librerías necesarias para el problema
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msng
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 10)

# %%
df = pd.read_csv('dataset_SCL.csv')

# %%
df.shape
# Out:
# (68206, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68206 entries, 0 to 68205
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha-I    68206 non-null  object
#  1   Vlo-I      68206 non-null  object
#  2   Ori-I      68206 non-null  object
#  3   Des-I      68206 non-null  object
#  4   Emp-I      68206 non-null  object
#  5   Fecha-O    68206 non-null  object
#  6   Vlo-O      68205 non-null  object
#  7   Ori-O      68206 non-null  object
#  8   Des-O      68206 non-null  object
#  9   Emp-O      68206 non-null  object
#  10  DIA        68206 non-null  int64
#  11  MES        68206 non-null  int64
#  12  AÑO        68206 non-null  int64
#  13  DIANOM     68206 non-null  object
#  14  TIPOVUELO  68206 non-null  object
#  15  OPERA      68206 non-null  object
#  16  SIGLAORI   68206 non-null  object
#  17  SIGLADES   68206 non-null  object
# dtypes: int64(3), object(15)
# memory usage: 9.4+ MB

# %%
msng.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 DIA           MES           AÑO
# count  68206.000000  68206.000000  68206.000000
# mean      15.714790      6.622585   2017.000029
# std        8.782886      3.523321      0.005415
# min        1.000000      1.000000   2017.000000
# 25%        8.000000      3.000000   2017.000000
# 50%       16.000000      7.000000   2017.000000
# 75%       23.000000     10.000000   2017.000000
# max       31.000000     12.000000   2018.000000

# %% [markdown]
# ### 1. ¿Cómo se distribuyen los datos? ¿Qué te llama la atención o cuál es tu conclusión sobre esto?

# %%
vuelos_aerolineas = df['OPERA'].value_counts()
plt.figure(figsize = (10,6))
sns.set(style="darkgrid")
sns.barplot(vuelos_aerolineas.index, vuelos_aerolineas.values, alpha=0.9)
plt.title('Cantidad de Vuelos por Aerlínea')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Aerlínea', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos_dia = df['DIA'].value_counts()
plt.figure(figsize = (10,6))
sns.set(style = "darkgrid")
sns.barplot(vuelos_dia.index, vuelos_dia.values, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por día del Mes')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Día del Mes', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos_mes = df['MES'].value_counts()
sns.set(style = "darkgrid")
sns.barplot(vuelos_mes.index, vuelos_mes.values, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por día del Mes')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Día del Mes', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos = df['DIANOM'].value_counts()
dias = [vuelos.index[2], vuelos.index[5], vuelos.index[4], vuelos.index[1], vuelos.index[0], vuelos.index[6], vuelos.index[3]]
valores_dias = [vuelos.values[2], vuelos.values[5], vuelos.values[4], vuelos.values[1], vuelos.values[0], vuelos.values[6], vuelos.values[3]]

sns.set(style="darkgrid")
sns.barplot(dias, valores_dias, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por Día de la Semana')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Día de la Semana', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos = df['TIPOVUELO'].value_counts()
sns.set(style="darkgrid")
sns.barplot(vuelos.index, vuelos.values, alpha=0.9)
plt.title('Cantidad de Vuelos por Tipo de Vuelo')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Tipo de Vuelo', fontsize=12)
plt.show()

# %%
vuelos = df['SIGLADES'].value_counts()
sns.set(style="darkgrid")
sns.barplot(vuelos.index, vuelos.values, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por Destino')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Destino', fontsize=12)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Respecto a las distribuciones, se puede ver que dentro de todo la data está distribuida de manera bastante balanceada. De todas formas se pueden notar ciertas particularidades en algunas columnas:
# * En las aerolíneas LATAM Airlines es la con mayor cantidad de vuelo debido a que es la más grande aquí en chile y es la que tiene mayor cantidad de destinos. SKY Airlines sería la segunda más grande y de ahí en adelante las demás son bastante similares en cuanto a vuelos.
# * En cuanto a los días del mes, se puede ver como el día 31 tiene menor cantidad que los demás días y esto se puede deber a que hay menos días 31 durante el año.
# * Con los días de semana, el día sábado es el único en el que se nota una diferencia. Aquí puede ser porque la gente prefiere ese día para quedarse en donde sea que esté y aprovecharlo en caso que esté de viaje para poder recorrer o solamente descansar.
# * Por parte de los destinos se puede ver que gran parte se lo llevan las ciudades chilenas del norte. Esto puede ser por un alto flujo en minería.

# %% [markdown]
# ### 2. Genera las columnas adicionales y luego expórtelas en un archivo synthetic_features.csv :

# %% [markdown]
# * **temporada_alta** : 1 si **Fecha-I** está entre 15-Dic y 3-Mar, o 15-Jul y 31-Jul, o 11-Sep y 30-Sep, 0 si no

# %%
from datetime import datetime

def temporada_alta(fecha):
    fecha_año = int(fecha.split('-')[0])
    fecha = datetime.strptime(fecha, '%Y-%m-%d %H:%M:%S')
    range1_min = datetime.strptime('15-Dec', '%d-%b').replace(year = fecha_año)
    range1_max = datetime.strptime('31-Dec', '%d-%b').replace(year = fecha_año)
    range2_min = datetime.strptime('1-Jan', '%d-%b').replace(year = fecha_año)
    range2_max = datetime.strptime('3-Mar', '%d-%b').replace(year = fecha_año)
    range3_min = datetime.strptime('15-Jul', '%d-%b').replace(year = fecha_año)
    range3_max = datetime.strptime('31-Jul', '%d-%b').replace(year = fecha_año)
    range4_min = datetime.strptime('11-Sep', '%d-%b').replace(year = fecha_año)
    range4_max = datetime.strptime('30-Sep', '%d-%b').replace(year = fecha_año)
    
    if ((fecha >= range1_min and fecha <= range1_max) or 
        (fecha >= range2_min and fecha <= range2_max) or 
        (fecha >= range3_min and fecha <= range3_max) or
        (fecha >= range4_min and fecha <= range4_max)):
        return 1
    else:
        return 0

# %%
df['temporada_alta'] = df['Fecha-I'].apply(temporada_alta)

# %%
df['temporada_alta'].value_counts()
# Out:
# 0    46174
# 1    22032
# Name: temporada_alta, dtype: int64

# %% [markdown]
# * **dif_min** : diferencia en minutos entre **Fecha-O** y **Fecha-I** .

# %%
def dif_min(data):
    fecha_o = datetime.strptime(data['Fecha-O'], '%Y-%m-%d %H:%M:%S')
    fecha_i = datetime.strptime(data['Fecha-I'], '%Y-%m-%d %H:%M:%S')
    dif_min = ((fecha_o - fecha_i).total_seconds())/60
    return dif_min

# %%
df['dif_min'] = df.apply(dif_min, axis = 1)

# %% [markdown]
# * **atraso_15** : 1 si **dif_min** > 15, 0 si no.

# %%
df['atraso_15'] = np.where(df['dif_min'] > 15, 1, 0)

# %%
df['atraso_15'].value_counts()
# Out:
# 0    55592
# 1    12614
# Name: atraso_15, dtype: int64

# %% [markdown]
# * **periodo_dia** : mañana (entre 5:00 y 11:59), tarde (entre 12:00 y 18:59) y noche (entre 19:00 y 4:59), en base a **Fecha-I**.

# %%
def get_periodo_dia(fecha):
    fecha_time = datetime.strptime(fecha, '%Y-%m-%d %H:%M:%S').time()
    mañana_min = datetime.strptime("05:00", '%H:%M').time()
    mañana_max = datetime.strptime("11:59", '%H:%M').time()
    tarde_min = datetime.strptime("12:00", '%H:%M').time()
    tarde_max = datetime.strptime("18:59", '%H:%M').time()
    noche_min1 = datetime.strptime("19:00", '%H:%M').time()
    noche_max1 = datetime.strptime("23:59", '%H:%M').time()
    noche_min2 = datetime.strptime("00:00", '%H:%M').time()
    noche_max2 = datetime.strptime("4:59", '%H:%M').time()
    
    if(fecha_time > mañana_min and fecha_time < mañana_max):
        return 'mañana'
    elif(fecha_time > tarde_min and fecha_time < tarde_max):
        return 'tarde'
    elif((fecha_time > noche_min1 and fecha_time < noche_max1) or
         (fecha_time > noche_min2 and fecha_time < noche_max2)):
        return 'noche'

# %%
df['periodo_dia'] = df['Fecha-I'].apply(get_periodo_dia)

# %%
df[['temporada_alta','dif_min','atraso_15','periodo_dia']].to_csv('synthetic_features.csv', index = False)

# %% [markdown]
# ### 3. ¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo? ¿Qué variables esperarías que más influyeran en predecir atrasos?

# %% [markdown]
# * ¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo?

# %%
def calcular_tasa(df, columna):
    
    dic_atrasos = {}
    for _, row in df.iterrows():
        if row['atraso_15'] == 1:
            if row[columna] not in dic_atrasos:
                dic_atrasos[row[columna]] = 1
            else:
                dic_atrasos[row[columna]] += 1
    
    total_values = df[columna].value_counts()
    
    dic_tasas = {}
    for name, total in total_values.iteritems():
        if name in dic_atrasos:
            dic_tasas[name] = round(total / dic_atrasos[name], 2)
        else:
            dic_tasas[name] = 0
            
    return pd.DataFrame.from_dict(data = dic_tasas, orient = 'index', columns = ['Tasa (%)'])

# %%
tasas_destinos = calcular_tasa(df, 'SIGLADES')
tasas_destinos
# Out:
#                 Tasa (%)
# Buenos Aires        3.91
# Antofagasta         6.83
# Lima                4.34
# Calama              8.18
# Puerto Montt        5.94
# ...                  ...
# Quito               1.00
# Washington          0.00
# Pisco, Peru         0.00
# Puerto Stanley      1.00
# Cochabamba          1.00
#
# [62 rows x 1 columns]

# %%
tasas_destinos_values = df['SIGLADES'].value_counts().index
plt.figure(figsize = (20,5))
sns.set(style="darkgrid")
sns.barplot(df['SIGLADES'].value_counts().index, tasas_destinos['Tasa (%)'], alpha = 0.75)
plt.title('Tasa de Retraso por Destino')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Destino', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
tasas_aerolineas = calcular_tasa(df, 'OPERA')
tasas_aerolineas
# Out:
#                           Tasa (%)
# Grupo LATAM                   5.60
# Sky Airline                   5.63
# Aerolineas Argentinas         4.16
# Copa Air                     15.95
# Latin American Wings          2.46
# Avianca                       3.76
# JetSmart SPA                  5.59
# Gol Trans                     2.81
# American Airlines            14.84
# Air Canada                    2.19
# Iberia                       10.06
# Delta Air                    17.05
# Air France                   11.93
# Aeromexico                   35.10
# United Airlines              19.71
# Oceanair Linhas Aereas        6.49
# Alitalia                      8.93
# K.L.M.                       11.95
# British Airways               7.07
# Qantas Airways                1.73
# Lacsa                         8.36
# Austral                       4.93
# Plus Ultra Lineas Aereas      1.63

# %%
tasas_aerolineas_values = df['OPERA'].value_counts().index

plt.figure(figsize = (10,5))
sns.set(style="darkgrid")
sns.barplot(tasas_aerolineas_values, tasas_aerolineas['Tasa (%)'], alpha = 0.75)
plt.title('Tasa de Retraso por Aerlínea')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Aerolínea', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
tasas_meses = calcular_tasa(df, 'MES')
tasas_meses
# Out:
#     Tasa (%)
# 12      3.94
# 1       6.25
# 11      5.07
# 10      4.43
# 7       3.41
# 8       5.77
# 9       5.80
# 2       6.60
# 3       8.69
# 5       6.34
# 4       8.58
# 6       5.85

# %%
tasas_meses_values = df['MES'].value_counts().index

plt.figure(figsize = (10,5))
sns.set(style="darkgrid")
sns.barplot(tasas_meses_values, tasas_meses['Tasa (%)'], color = 'blue', alpha = 0.75)
plt.title('Tasa de Retraso por Mes')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Meses', fontsize=12)
plt.xticks(rotation=90)
plt.ylim(0,10)
plt.show()

# %%
tasas_dias = calcular_tasa(df, 'DIANOM')
tasas_dias
# Out:
#            Tasa (%)
# Viernes        4.50
# Jueves         5.01
# Lunes          4.95
# Domingo        6.21
# Miercoles      5.85
# Martes         5.91
# Sabado         6.13

# %%
tasas_dias_values = df['DIANOM'].value_counts().index

sns.set(style="darkgrid")
plt.figure(figsize = (8,6))
sns.barplot(tasas_dias_values, tasas_dias['Tasa (%)'], color = 'blue', alpha = 0.75)
plt.title('Tasa de Retraso por Día')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Días', fontsize=12)
plt.xticks(rotation=90)
plt.ylim(0,7)
plt.show()

# %%
tasas_temporada = calcular_tasa(df, 'temporada_alta')
tasas_temporada
# Out:
#    Tasa (%)
# 0      5.58
# 1      5.08

# %%
tasas_temporada_values = df['temporada_alta'].value_counts().index

plt.figure(figsize = (8, 5))
sns.set(style="darkgrid")
sns.barplot(tasas_temporada_values, tasas_temporada['Tasa (%)'])
plt.title('Tasa de Retraso por Temporada')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Temporada', fontsize=12)
plt.xticks(rotation=90)
plt.ylim(0,6)
plt.show()

# %%
tasas_tipovuelo = calcular_tasa(df, 'TIPOVUELO')
tasas_tipovuelo
# Out:
#    Tasa (%)
# N      6.64
# I      4.43

# %%
tasas_tipovuelo_values = df['TIPOVUELO'].value_counts().index

plt.figure(figsize = (5,5))
sns.set(style="darkgrid")
sns.barplot(tasas_tipovuelo_values, tasas_tipovuelo['Tasa (%)'])
plt.title('Tasa de Retraso por Tipo de Vuelo')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Tipo de Vuelo', fontsize=12)
plt.ylim(0,7)
plt.show()

# %%
tasa_periododia = calcular_tasa(df, 'periodo_dia')
tasa_periododia
# Out:
#         Tasa (%)
# tarde       5.06
# mañana      6.21
# noche       5.02

# %%
tasas_periodo_values = df['periodo_dia'].value_counts().index

plt.figure(figsize = (5,5))
sns.set(style="darkgrid")
sns.barplot(tasas_periodo_values, tasa_periododia['Tasa (%)'])
plt.title('Tasa de Retraso por Periodo')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Tipo de Periodo', fontsize=12)
plt.ylim(3,7)
plt.show()

# %% [markdown]
# * ¿Qué variables esperarías que más influyeran en predecir atrasos?

# %% [markdown]
# Me parece que las que más podrían influir serían:
# * **Aerolíneas**: Dependiendo de la calidad de gestión de cada aerolínea puede ser que afecte en sus programaciones. También puede que afecte el tipo de aerolínea, si es una low cost por ejemplo, estas llevan menos equipaje ya que es un costo extra para cada pasajero por lo que el tiempo de carga es menor, corriendo menor riesgo de retraso.
# * **Tipo de Vuelo**: esto puede afectar en cómo esté el clima del país de destino. Por ejemplo si se tiene que volar a argentina y se tiene que cruzar por la cordillera y hay un mal clima, es posible que se tenga que esperar un rato para poder salir.
# * **Mes**: Esto va un poco de la mano con lo anterior, si es que es un mes del año donde el clima no es lo suficientemente adecuado, se tendría que esperar.

# %% [markdown]
# ### 4. Entrena uno o varios modelos (usando el/los algoritmo(s) que prefieras) para estimar la probabilidad de atraso de un vuelo. Siéntete libre de generar variables adicionales y/o complementar con variables externas.

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

# %%
data = shuffle(df[['OPERA', 'MES', 'TIPOVUELO', 'SIGLADES', 'DIANOM', 'atraso_15']], random_state = 111)

# %%
features = pd.concat([pd.get_dummies(data['OPERA'], prefix = 'OPERA'),pd.get_dummies(data['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data['MES'], prefix = 'MES')], axis = 1)
label = data['atraso_15']

# %%
x_train, x_test, y_train, y_test = train_test_split(features, label, test_size = 0.33, random_state = 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((45698, 37), (22508, 37))

# %%
y_train.value_counts('%')
# Out:
# 0    0.813799
# 1    0.186201
# Name: atraso_15, dtype: float64

# %%
y_test.value_counts('%')
# Out:
# 0    0.81762
# 1    0.18238
# Name: atraso_15, dtype: float64

# %% [markdown]
# #### Utilizando Regresión logística

# %%
logReg = LogisticRegression()
model = logReg.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# #### Métricas Regresión Logística

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[18311,    92],
#        [ 3985,   120]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90     18403
#            1       0.57      0.03      0.06      4105
#
#     accuracy                           0.82     22508
#    macro avg       0.69      0.51      0.48     22508
# weighted avg       0.77      0.82      0.75     22508

# %% [markdown]
# #### Utilizando XGBoost

# %%
import xgboost as xgb
from xgboost import plot_importance

# %%
modelxgb = xgb.XGBClassifier(random_state=1, learning_rate=0.01)
modelxgb = modelxgb.fit(x_train, y_train)
# Out:
# [20:47:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_predxgb = modelxgb.predict(x_test)

# %% [markdown]
# #### Métricas XGBoost

# %%
confusion_matrix(y_test, y_predxgb)
# Out:
# array([[18359,    44],
#        [ 4017,    88]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90     18403
#            1       0.57      0.03      0.06      4105
#
#     accuracy                           0.82     22508
#    macro avg       0.69      0.51      0.48     22508
# weighted avg       0.77      0.82      0.75     22508

# %% [markdown]
# #### Utilizando XGBoost dejando Features más importantes

# %%
modelxgb.feature_importances_
# Out:
# array([0.01000502, 0.03812766, 0.0774048 , 0.        , 0.        ,
#        0.05326247, 0.        , 0.        , 0.        , 0.11452038,
#        0.        , 0.05899746, 0.00510737, 0.        , 0.00056586,
#        0.        , 0.        , 0.03438188, 0.        , 0.00872514,
#        0.0687452 , 0.03494434, 0.02305363, 0.17575102, 0.        ,
#        0.01610017, 0.00777403, 0.02387431, 0.00835021, 0.01279221,
#        0.01183943, 0.06969901, 0.00991499, 0.01740215, 0.03937674,
#        0.02739293, 0.05189164], dtype=float32)

# %%
plt.figure(figsize = (13,10))
plot_importance(modelxgb)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
features_importantes = features[['MES_7', 'TIPOVUELO_I', 'OPERA_Copa Air', 'OPERA_Latin American Wings',
                                'MES_12', 'OPERA_Grupo LATAM', 'MES_10', 'OPERA_JetSmart SPA', 'OPERA_Air Canada',
                                'MES_9', 'OPERA_American Airlines']]
labels_ = label

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(features_importantes, labels_, test_size = 0.33, random_state = 42)

# %%
modelxgb = xgb.XGBClassifier(random_state=1, learning_rate=0.01, subsample = 1, max_depth = 10)
modelxgb = modelxgb.fit(x_train2, y_train2)
# Out:
# [20:47:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_predxgb = modelxgb.predict(x_test2)

# %% [markdown]
# #### Métricas XGBoost dejando Features más importantes

# %%
confusion_matrix(y_test2, y_predxgb)
# Out:
# array([[18371,    32],
#        [ 4044,    61]], dtype=int64)

# %%
print(classification_report(y_test2, y_predxgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90     18403
#            1       0.66      0.01      0.03      4105
#
#     accuracy                           0.82     22508
#    macro avg       0.74      0.51      0.46     22508
# weighted avg       0.79      0.82      0.74     22508

# %% [markdown]
# ### 5. Evalúa tu modelo. ¿Qué performance tiene? ¿Qué métricas usaste para evaluar esa performance y por qué? ¿Por qué elegiste ese algoritmo en particular? ¿Qué variables son las que más influyen en la predicción? ¿Cómo podrías mejorar laperformance?

# %% [markdown]
# Los modelos utilizados en la sección anterior fueron:
# * **Regresión Logística**: Fue seleccionado ya que es el modelo más simple para poder resolver problemas de clasificación.
# * **XGBoost**: Fue seleccionado porque en general tiene un gran desempeño y entrega buenos resultados ya sea para regresión y clasificación, además es bastante rápido y facilita el tuneo de hiperparámetros.
#
# Los resultados obtenidos con ambos modelos fueron muy malos. Se utilizó matriz de confusión para validar los resultados. La cantidad de falsos negativos fue muy alta. Una de las posibles razones, la más clara, es el desbalanceo que existe en la clase 'atraso_15'. Del total de datos un 82% corresponde a no atraso y el 18% restante a atraso.
# Para poder mejorar la performance se tomaron dos decisiones, la primera aplicar un Grid Search CV sobre XGBoost para tunear de mejor manera los hiperparámetros y la segunda realizar un upsampling de la clase desbalanceada, en este caso los atrasos.

# %% [markdown]
# ### Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
                'learning_rate': [0.01,0.05, 0.1],
                'n_estimators': [50, 100, 150],
                'subsample': [0.5, 0.9]
}

modelxgb_GridCV = GridSearchCV(modelxgb, param_grid = parameters,
    cv = 2, n_jobs=-1, verbose=1).fit(x_train, y_train)
# Out:
# Fitting 2 folds for each of 18 candidates, totalling 36 fits
# [20:44:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_predxgb_grid = modelxgb_GridCV.predict(x_test)

# %%
confusion_matrix(y_test, y_predxgb_grid)
# Out:
# array([[11058,    71],
#        [ 2421,    92]], dtype=int64)

# %%
print(classification_report(y_test, y_predxgb_grid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90     11129
#            1       0.56      0.04      0.07      2513
#
#     accuracy                           0.82     13642
#    macro avg       0.69      0.52      0.48     13642
# weighted avg       0.77      0.82      0.75     13642

# %% [markdown]
# ### Upsampling

# %%
data['atraso_15'].value_counts()
# Out:
# 0    55592
# 1    12614
# Name: atraso_15, dtype: int64

# %%
#Resample
from sklearn.utils import resample

data_no_retraso = data[data['atraso_15'] == 0]
data_atraso = data[data['atraso_15'] == 1]

data_atraso_upsampled = resample(data_atraso, 
                                 replace = True,     # sample with replacement
                                 n_samples = 30000,    # to match majority class
                                 random_state = 42) # reproducible results

data_upsampled = pd.concat([data_no_retraso, data_atraso_upsampled])

# %%
data_upsampled['atraso_15'].value_counts()
# Out:
# 0    55592
# 1    30000
# Name: atraso_15, dtype: int64

# %%
features_upsampled = pd.concat([pd.get_dummies(data_upsampled['OPERA'], prefix = 'OPERA'),pd.get_dummies(data_upsampled['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data_upsampled['MES'], prefix = 'MES')], axis = 1)
label_upsampled = data_upsampled['atraso_15']

# %%
x_upsampled_train, x_upsampled_test, y_upsampled_train, y_upsampled_test = train_test_split(features_upsampled, label_upsampled, test_size = 0.33, random_state = 42)

# %%
modelxgb = xgb.XGBClassifier(random_state=1, learning_rate=0.01, subsample = 1, max_depth = 10)
modelxgb.fit(x_upsampled_train, y_upsampled_train)
# Out:
# [19:49:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#               max_depth=10, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=1,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_upsampled_predxgb = modelxgb.predict(x_upsampled_test)

# %%
confusion_matrix(y_upsampled_test, y_upsampled_predxgb)
# Out:
# array([[17156,  1193],
#        [ 7969,  1928]], dtype=int64)

# %%
modelxgb.score(x_upsampled_test, y_upsampled_test)
# Out:
# 0.6756354882107201

# %%
print(classification_report(y_upsampled_test, y_upsampled_predxgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.79     18349
#            1       0.62      0.19      0.30      9897
#
#     accuracy                           0.68     28246
#    macro avg       0.65      0.56      0.54     28246
# weighted avg       0.66      0.68      0.62     28246

# %% [markdown]
# Observando los dos métodos para incrementar la performance, se puede ver como el modelo no mejoró. Esto puede ser ya que la data creada al upsamplear no tiene ningún sentido. Si se pudiese pudiese balancear la clase tal vez los modelos tendrían un mejor desempeño.

# %% [markdown]
# ## ML Engineer Challenge - LATAM Airlines

# %% [markdown]
# ### 1. Escoger el modelo que a tu criterio tenga un mejor performance, argumentando la decisión.

# %% [markdown]
# * El criterio de accuracy puede ser usado para la mayoría de los casos pero no es muy útil cuando se tienen datos no balanceados en la variable a predecir (como es en este caso), por lo que se usarán otras métricas.
# * Se usará el valor de AUC y ROC para comparar ambos modelos ya que es más útil cuando los modelos tienen datos no balanceados.

# %%
#Calculos de AUC para cada uno de los modelos

from sklearn import metrics
##Regresion logistica
#calculate AUC of model
auc_log = metrics.roc_auc_score(y_test, y_pred)

#print AUC score
print(auc_log)


##XGBoost
auc_xgboost = metrics.roc_auc_score(y_test, y_predxgb)

#print AUC score
print(auc_xgboost)


from sklearn.metrics import roc_auc_score
#calculate ROC AUC of model
roc_log = roc_auc_score(y_test, y_pred)

#print AUC score
print(roc_log)


##XGBoost
roc_xgboost = roc_auc_score(y_test, y_predxgb)

#print AUC score
print(roc_xgboost)
# Out:
# 0.5121167291013229
# 0.5065605399956304
# 0.5121167291013229
# 0.5065605399956304

# %% [markdown]
# ### Ambos modelos tiene valores de AUC y ROC, sin embargo, el modelo XGboosting es más robusto y funciona mejor cuando se posee una base de datos más grande, es por ello que se elegirá este modelo. (Otro modelo que se podría utlizar es Adaboost pero dado que se usaron estos 2 modelos no se usará)

# %% [markdown]
# ### 2. Implementar mejoras sobre el modelo escogiendo la o las técnicas que prefieras.

# %%
## Se aplica GridSearch para mejorar el modelo de XGBoost con los siguientes parametros
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
parameters = {
    "n_estimators":[5,50,250,500],
    "max_depth":[1,3,5,7,9],
    "learning_rate":[0.01,0.1,1,10,100]
}

from sklearn.model_selection import GridSearchCV

x_train,x_val, y_train, y_val = train_test_split(x_train, y_train, 
    test_size=0.25, random_state= 8) # 0.25 x 0.8 = 0.2

cv = GridSearchCV(gbc,parameters,cv=3)
cv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 1, 10, 100],
#                          'max_depth': [1, 3, 5, 7, 9],
#                          'n_estimators': [5, 50, 250, 500]})

# %%
def display(results):
    print(f'Best parameters are: {results.best_params_}')
    print("\n")
    mean_score = results.cv_results_['mean_test_score']
    std_score = results.cv_results_['std_test_score']
    params = results.cv_results_['params']
    for mean,std,params in zip(mean_score,std_score,params):
        print(f'{round(mean,3)} + or -{round(std,3)} for the {params}')
        
display(cv)
# Out:
# Best parameters are: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 500}
#
#
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 5}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 250}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# 0.815 + or -0.001 for the {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 250}
# 0.816 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}
# 0.817 + or -0.001 for the {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 250}
# 0.818 + or -0.001 for the {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 5}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}
# 0.818 + or -0.001 for the {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 250}
# 0.819 + or -0.001 for the {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 5}
# 0.815 + or -0.0 for the {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 50}
# 0.819 + or -0.001 for the {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 250}
# 0.819 + or -0.001 for the {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 5}
# 0.815 + or -0.0 for the {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50}
# 0.815 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 250}
# 0.815 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5}
# 0.817 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 0.818 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 250}
# 0.819 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5}
# 0.818 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# 0.819 + or -0.002 for the {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 250}
# 0.818 + or -0.002 for the {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 5}
# 0.819 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}
# 0.818 + or -0.002 for the {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 250}
# 0.818 + or -0.002 for the {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 500}
# 0.815 + or -0.0 for the {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 5}
# 0.818 + or -0.001 for the {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 50}
# 0.818 + or -0.002 for the {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 250}
# 0.818 + or -0.002 for the {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 500}
# 0.814 + or -0.0 for the {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 5}
# 0.816 + or -0.001 for the {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 50}
# 0.816 + or -0.001 for the {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 250}
# 0.816 + or -0.001 for the {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 500}
# 0.816 + or -0.0 for the {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 5}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 50}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 250}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 500}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 5}
# 0.818 + or -0.001 for the {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 50}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 250}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 500}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 5}
# 0.818 + or -0.001 for the {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 50}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 250}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 500}
# 0.817 + or -0.002 for the {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 5}
# 0.818 + or -0.001 for the {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 50}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 250}
# 0.818 + or -0.002 for the {'learning_rate': 1, 'max_depth': 9, 'n_estimators': 500}
# 0.185 + or -0.0 for the {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 5}
# 0.185 + or -0.0 for the {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 50}
# 0.185 + or -0.0 for the {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 250}
# 0.185 + or -0.0 for the {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 500}
# 0.186 + or -0.001 for the {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 5}
# 0.186 + or -0.001 for the {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 50}
# 0.186 + or -0.001 for the {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 250}
# 0.186 + or -0.001 for the {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 500}
# 0.23 + or -0.021 for the {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 5}
# 0.23 + or -0.021 for the {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 50}
# 0.23 + or -0.021 for the {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 250}
# 0.23 + or -0.021 for the {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 500}
# 0.428 + or -0.049 for the {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 5}
# 0.423 + or -0.056 for the {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 50}
# 0.423 + or -0.056 for the {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 250}
# 0.423 + or -0.056 for the {'learning_rate': 10, 'max_depth': 7, 'n_estimators': 500}
# 0.394 + or -0.084 for the {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 5}
# 0.391 + or -0.083 for the {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 50}
# 0.391 + or -0.083 for the {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 250}
# 0.391 + or -0.083 for the {'learning_rate': 10, 'max_depth': 9, 'n_estimators': 500}
# 0.437 + or -0.002 for the {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 5}
# 0.437 + or -0.002 for the {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 50}
# 0.437 + or -0.002 for the {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 250}
# 0.437 + or -0.002 for the {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 500}
# 0.47 + or -0.009 for the {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 5}
# 0.47 + or -0.009 for the {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 50}
# 0.47 + or -0.009 for the {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 250}
# 0.47 + or -0.009 for the {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 500}
# 0.462 + or -0.023 for the {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 5}
# 0.462 + or -0.023 for the {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 50}
# 0.462 + or -0.023 for the {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 250}
# 0.462 + or -0.023 for the {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 500}
# 0.437 + or -0.007 for the {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 5}
# 0.437 + or -0.007 for the {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 50}
# 0.437 + or -0.007 for the {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 250}
# 0.437 + or -0.007 for the {'learning_rate': 100, 'max_depth': 7, 'n_estimators': 500}
# 0.411 + or -0.052 for the {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 5}
# 0.411 + or -0.052 for the {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 50}
# 0.411 + or -0.052 for the {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 250}
# 0.411 + or -0.052 for the {'learning_rate': 100, 'max_depth': 9, 'n_estimators': 500}

# %% [markdown]
# ### El modelo escogido tiene los siguientes parámetros:
# * learning_rate = 0.01
# * max_depth = 7
# * n_estimators = 500

# %%
##XGBoost
y_predxgb_grid_cv = modelxgb_GridCV.predict(x_test)

auc_xgboost_cv = metrics.roc_auc_score(y_test, y_predxgb_grid_cv)

#print AUC score
print(auc_xgboost_cv)


from sklearn.metrics import roc_auc_score
#calculate ROC AUC of model
roc_xgboost_cv = roc_auc_score(y_test, y_predxgb_grid_cv)

#print AUC score
print(roc_xgboost_cv)
# Out:
# 0.5171518531870996
# 0.5171518531870996
